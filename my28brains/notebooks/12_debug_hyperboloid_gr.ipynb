# %%
import setcwd

setcwd.main()
# Out:
# Working directory:  /home/adele/code/my28brains/my28brains
# Directory added to path:  /home/adele/code/my28brains
# Directory added to path:  /home/adele/code/my28brains/my28brains
# Directory added to path:  /home/adele/code/my28brains/H2_SurfaceMatch
# Directory added to path:  /home/adele/code/my28brains/my28brains/notebooks
# Directory added to path:  /home/adele/code/my28brains/my28brains/notebooks/csv

# %%
import os
os.environ["GEOMSTATS_BACKEND"] = "pytorch"  # noqa: E402
import geomstats.backend as gs

import datasets.utils as data_utils

from my28brains.regression import training
# Out:
# INFO: Using pytorch backend
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [KeOps] Compiling cuda jit compiler engine ...
# [KeOps] Warning : There were warnings or errors compiling formula :
# /usr/bin/ld: cannot find -lnvrtc: No such file or directory
# collect2: error: ld returned 1 exit status
#
# OK
# [pyKeOps] Compiling nvrtc binder for python ...
# [KeOps] Warning : There were warnings or errors compiling formula :
# /usr/bin/ld: cannot find -lnvrtc: No such file or directory
# collect2: error: ld returned 1 exit status
#
# OK

# %%
null = 0
false = False
true = True

raw_config = {
  "n_X": {
    "desc": null,
    "value": 20
  },
  "_wandb": {
    "desc": null,
    "value": {
      "t": {
        "1": [
          1,
          5,
          53,
          55
        ],
        "2": [
          1,
          5,
          53,
          55
        ],
        "3": [
          2,
          15,
          17,
          23,
          37
        ],
        "4": "3.10.12",
        "5": "0.15.8",
        "8": [
          5
        ]
      },
      "framework": "torch",
      "start_time": 1699033550.387635,
      "cli_version": "0.15.8",
      "is_jupyter_run": false,
      "python_version": "3.10.12",
      "is_kaggle_kernel": false
    }
  },
  "full_run": {
    "desc": null,
    "value": false
  },
  "tol_factor": {
    "desc": null,
    "value": 0.1
  },
  "dataset_name": {
    "desc": null,
    "value": "hyperboloid"
  },
  "linear_noise": {
    "desc": null,
    "value": false
  },
  "noise_factor": {
    "desc": null,
    "value": 0
  },
  "space_dimension": {
    "desc": null,
    "value": 5
  },
  "linear_residuals": {
    "desc": null,
    "value": false
  },
  "project_linear_noise": {
    "desc": null,
    "value": false
  },
  "geodesic_initialization": {
    "desc": null,
    "value": "warm_start"
  }
}

# %%
class AttrDict(dict):
    """Convert a dict into an object where attributes are accessed with "."

    This is needed for the utils.load() function.
    """

    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self

# %%
config = {}
for key, value in raw_config.items():
    config[key] = value["value"]
config["dataset_name"]

config = AttrDict(config)

# %%
(
    space,
    y,
    y_noiseless,
    X,
    true_intercept,
    true_coef,
) = data_utils.load(config)
# Out:
# Creating synthetic dataset on hyperboloid
# intercept shape: torch.Size([6])
# coef shape: torch.Size([6])

# %%
tol = config.tol_factor


(
    linear_intercept_hat,
    linear_coef_hat,
    lr,
) = training.fit_linear_regression(y, X)

X_for_lr = gs.array(X.reshape(len(X), 1))
y_pred_for_lr = lr.predict(X_for_lr)
y_pred_for_lr = y_pred_for_lr.reshape(y.shape)

(
    geodesic_intercept_hat,
    geodesic_coef_hat,
    gr,
) = training.fit_geodesic_regression(
    y,
    space,
    X,
    tol=tol,
    intercept_hat_guess=linear_intercept_hat,
    coef_hat_guess=linear_coef_hat,
    initialization=config.geodesic_initialization,
    linear_residuals=config.linear_residuals,
)
# Out:
# y.shape:  torch.Size([20, 6])
# X.shape:  torch.Size([20])
# y.shape:  torch.Size([20, 6])
# initialization: warm_start
# linear_residuals: False
# Intercept guess:  torch.Size([6])
# Coef guess:  torch.Size([6])
# y.shape:  torch.Size([20, 6])
# X.shape:  torch.Size([20])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# base_point tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# intercept belongs to space: tensor(True)
# tensor([1.3170, 0.3761, 0.2441, 0.4892, 0.3427, 0.4203])
# coef belongs to tangent space: tensor(True)
# tensor([0.5321, 0.3688, 0.4065, 0.4001, 0.3989, 0.3103])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# base_point tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# intercept belongs to space: tensor(True)
# tensor([1.7319, 0.6189, 0.3771, 0.8168, 0.5547, 0.7067])
# coef belongs to tangent space: tensor(True)
# tensor([1.0355, 0.5686, 0.5330, 0.6615, 0.5798, 0.5356])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6392, 1116.8449, 1217.7791, 1217.8422, 1203.1137,  947.5979])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6392, 1116.8449, 1217.7791, 1217.8422, 1203.1137,  947.5979])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1146,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1146,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# in loss function
# tangent_vec tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# base_point tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# intercept belongs to space: tensor(True)
# tensor([56.9924, 24.8501, 27.0955, 27.0975, 26.7695, 21.0846])
# coef belongs to tangent space: tensor(True)
# tensor([2560.6409, 1116.8456, 1217.7799, 1217.8430, 1203.1145,  947.5985])
# X tensor([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
#         -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
#          0.3421,  0.3947,  0.4474,  0.5000])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 18
#      11 y_pred_for_lr = lr.predict(X_for_lr)
#      12 y_pred_for_lr = y_pred_for_lr.reshape(y.shape)
#      14 (
#      15     geodesic_intercept_hat,
#      16     geodesic_coef_hat,
#      17     gr,
# ---> 18 ) = training.fit_geodesic_regression(
#      19     y,
#      20     space,
#      21     X,
#      22     tol=tol,
#      23     intercept_hat_guess=linear_intercept_hat,
#      24     coef_hat_guess=linear_coef_hat,
#      25     initialization=config.geodesic_initialization,
#      26     linear_residuals=config.linear_residuals,
#      27 )
#
# File ~/code/my28brains/my28brains/regression/training.py:163, in fit_geodesic_regression(y, space, X, tol, intercept_hat_guess, coef_hat_guess, initialization, linear_residuals, compute_iterations)
#     160 print("y.shape: ", y.shape)
#     161 print("X.shape: ", X.shape)
# --> 163 gr.fit(gs.array(X), gs.array(y))
#     165 intercept_hat, coef_hat = gr.intercept_, gr.coef_
#     167 return intercept_hat, coef_hat, gr
#
# File ~/code/my28brains/my28brains/regression/geodesic_regression.py:432, in GeodesicRegression.fit(self, X, y, weights)
#     429     X -= self.mean_
#     431 if self.method == "extrinsic":
# --> 432     res = self._fit_extrinsic(X, y, weights)
#     433 if self.method == "riemannian":
#     434     res = self._fit_riemannian(X, y, weights)
#
# File ~/code/my28brains/my28brains/regression/geodesic_regression.py:479, in GeodesicRegression._fit_extrinsic(self, X, y, weights)
#     473 initial_guess = gs.hstack([gs.flatten(intercept_hat), gs.flatten(coef_hat)])
#     475 objective_with_grad = lambda param: self._loss(  # noqa E731
#     476     X, y, param, weights
#     477 )
# --> 479 result = self.optimizer.minimize(
#     480     objective_with_grad,
#     481     initial_guess,
#     482 )
#     484 if self.compute_iterations:
#     485     n_iterations = result.nit
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/geomstats/numerics/optimizers.py:87, in ScipyMinimize.minimize(self, fun, x0, fun_jac, fun_hess, hessp)
#      84 fun_, jac = self._handle_jac(fun, fun_jac)
#      85 hess = self._handle_hess(fun_hess)
# ---> 87 result = scipy.optimize.minimize(
#      88     fun_,
#      89     x0,
#      90     method=self.method,
#      91     jac=jac,
#      92     hess=hess,
#      93     hessp=hessp,
#      94     bounds=self.bounds,
#      95     tol=self.tol,
#      96     constraints=self.constraints,
#      97     callback=self.callback,
#      98     options=self.options,
#      99 )
#     101 result = result_to_backend_type(result)
#     103 if result.status > 0:
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_minimize.py:703, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     701     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     702 elif meth == 'cg':
# --> 703     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     704 elif meth == 'bfgs':
#     705     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_optimize.py:1809, in _minimize_cg(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1805     return np.dot(pk, gfk) <= -sigma_3 * np.dot(gfk, gfk)
#    1807 try:
#    1808     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1809              _line_search_wolfe12(f, myfprime, xk, pk, gfk, old_fval,
#    1810                                   old_old_fval, c2=0.4, amin=1e-100, amax=1e100,
#    1811                                   extra_condition=descent_condition)
#    1812 except _LineSearchError:
#    1813     # Line search failed to find a better solution.
#    1814     warnflag = 2
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_optimize.py:1215, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1201 """
#    1202 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1203 suitable step length is not found, and raise an exception if a
#    (...)
#    1210
#    1211 """
#    1213 extra_condition = kwargs.pop('extra_condition', None)
# -> 1215 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1216                          old_fval, old_old_fval,
#    1217                          **kwargs)
#    1219 if ret[0] is not None and extra_condition is not None:
#    1220     xp1 = xk + ret[0] * pk
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:84, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      80     return np.dot(gval[0], pk)
#      82 derphi0 = np.dot(gfk, pk)
# ---> 84 stp, fval, old_fval = scalar_search_wolfe1(
#      85         phi, derphi, old_fval, old_old_fval, derphi0,
#      86         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      88 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:161, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     159     alpha1 = stp
#     160     phi1 = phi(stp)
# --> 161     derphi1 = derphi(stp)
#     162 else:
#     163     break
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:78, in line_search_wolfe1.<locals>.derphi(s)
#      77 def derphi(s):
# ---> 78     gval[0] = fprime(xk + s*pk, *args)
#      79     gc[0] += 1
#      80     return np.dot(gval[0], pk)
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:273, in ScalarFunction.grad(self, x)
#     271 if not np.array_equal(x, self.x):
#     272     self._update_x_impl(x)
# --> 273 self._update_grad()
#     274 return self.g
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/geomstats/numerics/optimizers.py:59, in ScipyMinimize._handle_jac.<locals>.fun_(x)
#      58 def fun_(x):
# ---> 59     return fun(gs.from_numpy(x))
#
# File ~/code/my28brains/my28brains/regression/geodesic_regression.py:475, in GeodesicRegression._fit_extrinsic.<locals>.<lambda>(param)
#     472 coef_hat = self.space.to_tangent(coef_init, intercept_hat)
#     473 initial_guess = gs.hstack([gs.flatten(intercept_hat), gs.flatten(coef_hat)])
# --> 475 objective_with_grad = lambda param: self._loss(  # noqa E731
#     476     X, y, param, weights
#     477 )
#     479 result = self.optimizer.minimize(
#     480     objective_with_grad,
#     481     initial_guess,
#     482 )
#     484 if self.compute_iterations:
#
# File ~/code/my28brains/my28brains/regression/geodesic_regression.py:351, in GeodesicRegression._loss(self, X, y, param, weights)
#     348     print("tangent_vec", tangent_vec)
#     349     print("base_point", base_point)
#     350     distances = self.space.metric.squared_dist(
# --> 351         self._model(X, tangent_vec, base_point), y
#     352     )
#     354 if weights is None:
#     355     weights = 1.0
#
# File ~/code/my28brains/my28brains/regression/geodesic_regression.py:306, in GeodesicRegression._model(self, X, coef, intercept)
#     303 print("X", X)
#     304 print
# --> 306 return self.space.metric.exp(gs.einsum("n,...->n...", X, coef), intercept)
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/geomstats/geometry/hyperboloid.py:269, in HyperboloidMetric.exp(self, tangent_vec, base_point)
#     261 coef_2 = utils.taylor_exp_even_func(
#     262     sq_norm_tangent_vec, utils.sinch_close_0, order=5
#     263 )
#     265 exp = gs.einsum("...,...j->...j", coef_1, base_point) + gs.einsum(
#     266     "...,...j->...j", coef_2, tangent_vec
#     267 )
# --> 269 return self._space.regularize(exp)
#
# File ~/anaconda3/envs/my28brains1/lib/python3.10/site-packages/geomstats/geometry/hyperboloid.py:112, in Hyperboloid.regularize(self, point)
#     110 sq_norm = self.embedding_space.metric.squared_norm(point)
#     111 if not gs.all(sq_norm):
# --> 112     raise ValueError(
#     113         "Cannot project a vector of norm 0. in the "
#     114         "Minkowski space to the hyperboloid"
#     115     )
#     116 real_norm = gs.sqrt(gs.abs(sq_norm))
#     117 return gs.einsum("...i,...->...i", point, 1.0 / real_norm)
#
# ValueError: Cannot project a vector of norm 0. in the Minkowski space to the hyperboloid

# %%
intercept = gs.array([56.9922, 24.8500, 27.0954, 27.0974, 26.7694, 21.0845])
#coef belongs to tangent space: tensor(True)
coef =  gs.array([2560.6206, 1116.8364, 1217.7700, 1217.8336, 1203.1051,  947.5913])

X =  gs.array([-0.5000, -0.4474, -0.3947, -0.3421, -0.2895, -0.2368, -0.1842, -0.1316,
        -0.0789, -0.0263,  0.0263,  0.0789,  0.1316,  0.1842,  0.2368,  0.2895,
         0.3421,  0.3947,  0.4474,  0.5000])

# %%
exp = space.metric.exp(gs.einsum("n,...->n...", X, coef), intercept)
# space.regularize(exp)

# %%
import math
import geomstats.algebra_utils as utils
import geomstats.backend as gs
from geomstats.geometry._hyperbolic import HyperbolicMetric, _Hyperbolic
from geomstats.geometry.base import LevelSet
from geomstats.geometry.minkowski import Minkowski

#exp function in hyperboloid
tangent_vec = gs.einsum("n,...->n...", X, coef)
base_point = intercept

sq_norm_tangent_vec = space.embedding_space.metric.squared_norm(
    tangent_vec
)
sq_norm_tangent_vec = gs.clip(sq_norm_tangent_vec, 0, math.inf)
print("sq_norm_tangent_vec", sq_norm_tangent_vec)
coef_1 = utils.taylor_exp_even_func(
    sq_norm_tangent_vec, utils.cosh_close_0, order=5
)
coef_2 = utils.taylor_exp_even_func(
    sq_norm_tangent_vec, utils.sinch_close_0, order=5
)

exp = gs.einsum("...,...j->...j", coef_1, base_point) + gs.einsum(
    "...,...j->...j", coef_2, tangent_vec
)
print("this exp should be weird", exp)

space.regularize(exp)

# %%
sq_norm = space.embedding_space.metric.squared_norm(coef)

# %%
sq_norm

# %%
exp_norm_0 = gs.array([ 2.8793e+09,  1.2557e+09,  1.3691e+09,  1.3692e+09,  1.3526e+09,
          1.0654e+09])

# %%
space.embedding_space.metric.squared_norm(exp_norm_0)

# %%
gs.all(1.6137e+14)
